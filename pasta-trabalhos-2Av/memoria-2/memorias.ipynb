# %% [markdown]
# PROJETO 1:

# %% [markdown]
# Projete um sistema de memória que possui 13 pinos de endereços e um barramento de dados (BD) que transporta 2 palavras por vez. O BD não pode exceder 64 bits e a palavra deve ser maior que a célula da memória. A memória deve ter capacidade de 8 Gbits. Depois do projeto, indique qual é o tamanho da palavra, da célula, do BD e do barramento de endereços, e desenhe o chip.

# %%
from IPython.display import Image
Image(filename="00.png")

# %% [markdown]
# Essa memória contém RAS = 13 pinos, CAS = 14 e 32 Bancos de Dados. Desse modo, o tamanho do endereço será de 2Gb e as células terão 4 bits de tamanho. Atendendo as requisitos do BD, que transporta 2 palavras por vez e esta devendo ser maior que a célula, a palavra dessa memória terá tamanho de 8bits, seu BE terá tamanho de 20 bits e seu barramento de dados terá 16 pinos, uma vez que o BD transporta 2 palavras por vez.

# %%
ras = 1
cas = 1
pinos_ras = 13
pinos_cas = 13
bd = 5
tamanho_celula = 4
bd_transporte = 2 * 1
tamanho_palavra = 8
tamanho_be = bd + pinos_ras + ras + cas
pinos_barramento_dados = bd_transporte * tamanho_palavra
total_necessario = 2 ** 33
total = (2 ** pinos_ras) * (2 ** pinos_cas) * (2 ** bd) * tamanho_celula
if total == total_necessario:
    print("OK")
    if tamanho_palavra > tamanho_celula:
        print("OK")
        print(f"Serão necessários {pinos_barramento_dados} pinos no BD")
        print(f"Tamanho do BE: {tamanho_be}")
# Out:
# OK
# OK
# Serão necessários 16 pinos no BD
# Tamanho do BE: 20

# %% [markdown]
# PROJETO 2:

# %% [markdown]
# Projete um sistema de memória que possui 16 linhas de dados (BD). Os pinos de endereço precisam ser menores que 14. A memória deve ter capacidade de 32 Gbits. Justifique cada decisão do projeto. Desenhe o chip. Qual é o tamanho do barramento de endereços?

# %%
from IPython.display import Image
Image(filename="01.png")

# %% [markdown]
# A segunda memória contém RAS = 13 pinos e CAS = 13, e 32 Bancos. O tamanho do endereço será de 2GB e as células terão 16 bits de tamanho. Por fim, como especificado, o BD terá 16 pinos, o BE terá tamanho de 20 bits. Assim, o tamanho da memória será de 32Gb.

# %%
ras2 = 1
cas2 = 1
pinos_ras2 = 13
pinos_cas2 = 13
bd2 = 5
tamanho_celula2 = 16
tamanho_be2 = bd2 + pinos_ras2 + ras2 + cas2
total_necessario2 = 2 ** 35
total2 = (2 ** pinos_ras2) * (2 ** pinos_cas2) * (2 ** bd2) * tamanho_celula2
if total2 == total_necessario2:
    print("OK")
    print(f"Tamanho do BE: {tamanho_be2}")
else:
    print("Errado")
# Out:
# OK
# Tamanho do BE: 20

# %% [markdown]
# FIM
